# %%
# Import dependencies and setup

import geopandas as gpd

# %%
# Read geojson file and store as DataFrame

median_income_df = gpd.read_file('static/data/vic_median_household_income_2016.geojson')
median_income_df.head()
# Out:
#    OBJECTID      GEOID10 COUNTYFP10 TRACTCE10 Cnty_Name       City_Name  \
# 0        11  06025010101        025    010101  Imperial
# 1       213  06059980000        059    980000                   Anaheim
# 2       229  06059021813        059    021813                   Anaheim
# 3       833  06071980100        071    980100            San Bernardino
# 4       878  06071012300        071    012300            San Bernardino
#
#      ZIP         Acres        SqMi  Pop_16  ...  UnEmp_Rate Emp_15  \
# 0  92233  93903.349290  146.723983    4223  ...    0.101266   1454
# 1  92802    683.188267    1.067482      25  ...    0.000000  30340
# 2  92807   1159.678407    1.811998     102  ...    0.000000  19437
# 3  92408   1982.388981    3.097483       0  ...    0.000000  11200
# 4  92346    211.696199    0.330775    4400  ...    0.269231   2952
#
#         Emp_Den    Emp_Src  Income_Pct  Income_Rpt  Income_Src  Under19_Pc  \
# 0      9.909764  LEHD 2015           0                                 2.0
# 1  28422.033762  LEHD 2015           0                                60.0
# 2  10726.835928  LEHD 2015           0                                30.4
# 3   3615.839308  LEHD 2015           0                                 0.0
# 4   8924.487123  LEHD 2015           0                                 0.0
#
#    MHI2016                                           geometry
# 0      NaN  POLYGON ((-115.64096 33.35902, -115.64096 33.3...
# 1      NaN  POLYGON ((-117.91511 33.81539, -117.91537 33.8...
# 2      NaN  POLYGON ((-117.83125 33.86212, -117.83125 33.8...
# 3      NaN  POLYGON ((-117.25971 34.10356, -117.25971 34.1...
# 4      NaN  POLYGON ((-117.22623 34.13691, -117.22623 34.1...
#
# [5 rows x 39 columns]

# %%
# Query datatypes

median_income_df.dtypes
# Out:
# OBJECTID         int64
# GEOID10         object
# COUNTYFP10      object
# TRACTCE10       object
# Cnty_Name       object
# City_Name       object
# ZIP              int64
# Acres          float64
# SqMi           float64
# Pop_16           int64
# Pop_Den          int64
# Pop_Src         object
# Pop_10           int64
# White_Pct      float64
# Black_Pct      float64
# Asian_Pct      float64
# Latino_Pct     float64
# Mltpl_Pct      float64
# NatAm_Pct      float64
# PacIs_Pct      float64
# Other_Pct      float64
# NonWhite_P     float64
# Race_Src        object
# Elders_Pct     float64
# Elders_Rpt      object
# Elders_Src      object
# SpksEng_Pc     float64
# SpksEng_Rp      object
# SpksEng_Sr      object
# UnEmp_Rate     float64
# Emp_15           int64
# Emp_Den        float64
# Emp_Src         object
# Income_Pct       int64
# Income_Rpt      object
# Income_Src      object
# Under19_Pc     float64
# MHI2016        float64
# geometry      geometry
# dtype: object
